# %% [markdown]
# # Projet ML test

# %% [markdown]
# ### Nétoyage de la donnée

# %%
import pandas as pd

df = pd.read_csv('kaggle_b2_fraud_train.csv')
df.head()
# Out:
#        customer_id        account_id  age  tenure_months  annual_income_eur  \
# 0  CUST_7O7B4OC888  ACC_TACKQKWHFB2I   18             42           12604.31
# 1  CUST_G5D9HCKEYD  ACC_EN7OC1DLMQUQ   25             11           36133.60
# 2  CUST_5YHBCQWI3O  ACC_J38B0G2XTCUS   23             11           29528.32
# 3  CUST_RF6DJEUOOU  ACC_6F99QLXXUP0X   18              6           28247.85
# 4  CUST_WNVVULGQE7  ACC_91BZO39DAE2T   30             48           13978.11
#
#    credit_score  num_transactions_30d  avg_amount_30d_eur  max_amount_30d_eur  \
# 0         715.0                    18               41.22              253.57
# 1         675.0                    19               65.60              523.45
# 2         667.0                    28                 NaN              258.13
# 3         630.0                    18              198.03              316.96
# 4         626.0                    21              127.85              851.10
#
# ...
